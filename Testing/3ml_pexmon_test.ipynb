# %%
#for the testing dir
import sys
sys.path.append("..")

from pexmon_3ml import Pexmon
from threeML import Model
import numpy as np
import matplotlib.pyplot as plt

# %%
pexmon = Pexmon()
E_bins = np.logspace(-1, 5, 100)

# %%
calc_pexmon = pexmon(E_bins)
# Out:
# Neutral Compton reflection with Fe emission
# Fe line: George & Fabian 1991, 249, 352
# Reflection: Magdziarz & Zdziarski 1995 MNRAS
# Full description in: Nandra et al. 2007, MNRAS

# %%
pexmon.free_parameters
# Out:
# OrderedDict([('Gamma',
#               Parameter Gamma = 2.0 []
#               (min_value = -2.0, max_value = 9.0, delta = 0.1, free = True))])

# %%
import matplotlib.pyplot as plt
plt.loglog(E_bins, calc_pexmon)
# plt.xlabel("Energy (keV)")
# plt.ylabel("Photon Flux")
# plt.title("Pexmon Model Spectrum")
plt.show()
