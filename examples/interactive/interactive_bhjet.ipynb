# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib widget

# %%
from bhjet_explorer import BHJetExplorer
# Out:
# 12:29:39 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=915767;file:///home/mklinge1/micromamba/envs/fitting/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=108319;file:///home/mklinge1/micromamba/envs/fitting/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py#43\43]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=339141;file:///home/mklinge1/micromamba/envs/fitting/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=549615;file:///home/mklinge1/micromamba/envs/fitting/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py#65\65]8;;\
#                   will not be available.
# ...

# %%
# Instantiate with source-specific defaults.
# All constructor arguments are optional — omit any to use the built-in defaults.
explorer = BHJetExplorer(
    verbosity_level   = 0,
    Emin_eV           = 1e-10,
    Emax_eV           = 1e15,
)
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
# %matplotlib widget

# %%
# Override any starting parameter value before displaying.
# This is equivalent to dragging the slider to that value.
# explorer.set_param("lg_mass_bh",               9.0)
# explorer.set_param("lg_jet_power_eddington",   -5.0)
# explorer.set_param("lg_z_dissipation",          2.0)
# explorer.set_param("index_injected_electrons",  2.0)

# %% [markdown]
# if the cell below gives an error, run the cells above again, and try again

# %%
# %matplotlib widget
# Render: SED canvas on top, tabbed sliders below.
explorer.display()

# %%
explorer.display_zones()

# %%
explorer
