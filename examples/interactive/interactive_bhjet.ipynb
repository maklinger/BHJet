# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib widget

# %%
use_threeML_plugins = True
if use_threeML_plugins:
    from bhjet_explorer_3ml import BHJetExplorer3ML as BHJetExplorer
else:
    from bhjet_explorer import BHJetExplorer
# Out:
# 15:41:17 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=869784;file:///home/mklinge1/micromamba/envs/fitting/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=298841;file:///home/mklinge1/micromamba/envs/fitting/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py#43\43]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=739435;file:///home/mklinge1/micromamba/envs/fitting/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=226005;file:///home/mklinge1/micromamba/envs/fitting/lib/python3.11/site-packages/astromodels/functions/functions_1D/functions.py#65\65]8;;\
#                   will not be available.
# 15:41:18 WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=377646;file:///home/mklinge1/micromamba/envs/fitting/lib/python3.11/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=237566;file:///home/mklinge1/micromamba/envs/fitting/lib/python3.11/site-packages/astromodels/functions/functions_1D/absorption.py#33\33]8;;\
#                   available

# %%
# Instantiate with source-specific defaults.
# All constructor arguments are optional — omit any to use the built-in defaults.
explorer = BHJetExplorer(
    include_counterjet= True,
    compton_threshold = 1e-5,
    dlgz              = 0.1,
    verbosity_level   = 0,
    Emin_eV           = 1e-6,
    Emax_eV           = 1e15,
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Override any starting parameter value before displaying.
# This is equivalent to dragging the slider to that value.
explorer.set_param("lg_mass_bh",               9.0)
explorer.set_param("lg_jet_power_eddington",   -5.0)
explorer.set_param("lg_z_dissipation",          2.0)
explorer.set_param("index_injected_electrons",  2.0)

# %%
# Render: SED canvas on top, tabbed sliders below.
explorer.display()
# Out:
# VBox(children=(Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Ba…
